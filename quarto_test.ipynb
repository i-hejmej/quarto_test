# %% [markdown]
# ---
# title: "Test Project"
# date: "27/04/2026"
# author: "Ignacy Hejmej"
# execute:
#     enabled: true
# ---

# %%
import numpy as np
x = np.atan(1)*4
print(x)
# Out:
# 3.141592653589793

# %% [markdown]
# The value of $\pi$ is `{python} f"{x:.4g}"`
